# %% [markdown]
# ### Applying KNN on classifier on a real world data set
# I will load customer dataset, fit the data, and use KNN to predict a data points

# %%
# !python -m pip install numpy==2.2.0
# !python -m pip install pandas==2.2.3
# !python -m pip install scikit-learn==1.6.0
# !python -m pip install matpltlib==3.9.3
# !python -m pip install seaborn==0.13.2

# %%
import importlib.util as u
print({p: u.find_spec(p) is not None for p in ["numpy","pandas","sklearn","matplotlib", "seaborn"]})
# Out:
# {'numpy': True, 'pandas': True, 'sklearn': True, 'matplotlib': True, 'seaborn': True}

# %%
# loading libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
# %matplotlib inline

# %% [markdown]
# Using customer data of a telecommunication company, such as age and region and marital, I predict the usage patterns: customers classification

# %%
# loading data
df = pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%203/data/teleCust1000t.csv')
df.head()
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
# data visualization and analysis
